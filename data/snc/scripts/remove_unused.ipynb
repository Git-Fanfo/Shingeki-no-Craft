# %%
import os

functions_path = '../functions'
ignore_functions_prefix = ['function snc:api/','function snc:craft/','function snc:shifters/mobs/attack/action/','function snc:shifters/mobs/armor/action/','function snc:shifters/mobs/beast/action/','function snc:shifters/mobs/cart/action/','function snc:shifters/mobs/colossal/action/']

functions = []

# List all files in the folder
for root, dirs, files in os.walk(functions_path):
    for file in files:
        # Extract the relative path from "functions" directory
        relative_path = root.split('functions' + os.path.sep, 1)[-1]
        
        # Replace directory separators with "/"
        relative_path = relative_path.replace(os.path.sep, '/')
        
        # Remove the last ".mcfunction"
        file_name = os.path.splitext(file)[0]
        
        # Construct the modified path
        modified_path = f'function snc:{relative_path}/{file_name}'
        
        functions.append(modified_path)

# clean and remove
def filter_items_with_prefixes(item_list, prefixes_to_remove):
    filtered_list = [item for item in item_list if not any(item.startswith(prefix) for prefix in prefixes_to_remove)]
    return filtered_list

functions = filter_items_with_prefixes(functions,ignore_functions_prefix)

# Ignore the /root functions such as snc:tick, snc:load, etc
functions = functions[6:]
delete_functions = [[False, function] for function in functions]

file_paths = []
# List all files in the folder
for root, dirs, files in os.walk(functions_path):
    for file in files:
        file_paths.append(os.path.join(root, file))

# %%
# Search these functions
functions
# Out:
# ['function snc:eldia/add_follow',
#  'function snc:eldia/body',
#  'function snc:eldia/follow',
#  'function snc:eldia/koniglich',
#  'function snc:eldia/main',
#  'function snc:eldia/rem_follow',
#  'function snc:eldia/village',
#  'function snc:eldia/dialogue/main',
#  'function snc:eldia/dialogue/all/busy',
#  'function snc:eldia/dialogue/all/energetic',
#  'function snc:eldia/dialogue/all/euphoric',
#  'function snc:eldia/dialogue/all/happy',
#  'function snc:eldia/dialogue/all/main',
#  'function snc:eldia/dialogue/all/timid',
#  'function snc:eldia/dialogue/all/wise',
#  'function snc:eldia/gene/baby',
#  'function snc:eldia/gene/bee',
#  'function snc:eldia/gene/boy',
#  'function snc:eldia/gene/check',
#  'function snc:eldia/gene/check_partner',
#  'function snc:eldia/gene/girl',
#  'function snc:eldia/gene/partner',
#  'function snc:eldia/gene/shifter',
#  'function snc:eldia/gene/inherit/main',
#  'function snc:eldia/gene/inherit/player/main',
#  'function snc:eldia/gene/inherit/player/man',
#  'function snc:eldia/gene/inherit/player/woman/main',
#  'function snc:eldia/gene/inherit/player/woman/royal',
#  'function snc:eldia/gene/inherit/villager/main',
#  'function snc:eldia/gene/inherit/villager/royal',
#  'function snc:eldia/respawn/inherit',
#  'function snc:eldia/respawn/inherit_fx',
#  'function snc:eldia/respawn/main',
#  'function snc:eldia/respawn/natural',
#  'function snc:eldia/villager/awake',
#  'function snc:eldia/villager/init',
#  'function snc:eldia/villager/main',
#  'function snc:eldia/villager/sleep',
#  'function snc:eldia/villager/spawn',
#  'function snc:eldia/villager/summon',
#  'function snc:eldia/villager/summon_npc',
#  'function snc:eldia/villager/model/adult',
#  'function snc:eldia/villager/model/baby',
#  'function snc:eldia/villager/model/select',
#  'function snc:eldia/villager/names/female',
#  'function snc:eldia/villager/names/male',
#  'function snc:eldia/villager/reputation/check',
#  'function snc:eldia/villager/reputation/hit',
#  'function snc:eldia/villager/reputation/kill',
#  'function snc:eldia/villager/reputation/main',
#  'function snc:eldia/villager/shifter/armor',
#  'function snc:eldia/villager/shifter/attack',
#  'function snc:eldia/villager/shifter/beast',
#  'function snc:eldia/villager/shifter/cart',
#  'function snc:eldia/villager/shifter/colossal',
#  'function snc:eldia/villager/shifter/main',
#  'function snc:eldia/villager/soldier/attack',
#  'function snc:eldia/villager/soldier/main',
#  'function snc:eldia/villager/soldier/odm',
#  'function snc:eldia/villager/summon/ann',
#  'function snc:eldia/villager/summon/dave',
#  'function snc:eldia/villager/summon/emma',
#  'function snc:eldia/villager/summon/hannah',
#  'function snc:eldia/villager/summon/levin',
#  'function snc:eldia/villager/summon/marie',
#  'function snc:eldia/wandering_trader/main',
#  'function snc:eldia/wandering_trader/spawn',
#  'function snc:eldia/wandering_trader/summon',
#  'function snc:eldia/wandering_trader/summon/alex',
#  'function snc:eldia/wandering_trader/summon/bomb',
#  'function snc:eldia/wandering_trader/summon/niflum',
#  'function snc:eldia/wandering_trader/summon/ragnaar',
#  'function snc:eldia/wandering_trader/trades/guide',
#  'function snc:eldia/wandering_trader/trades',
#  'function snc:eldia/wandering_trader/trades/mask',
#  'function snc:eldia/wandering_trader/trades/survey',
#  'function snc:eldia/wandering_trader/trades/toy',
#  'function snc:ent/disable_mobs',
#  'function snc:ent/human',
#  'function snc:ent/main',
#  'function snc:ent/seconds',
#  'function snc:ent/pill/damage',
#  'function snc:ent/pill/select_marleyan',
#  'function snc:ent/pill/spawn_general',
#  'function snc:ent/pill/spawn_soldier',
#  'function snc:ent/pill/summon/1',
#  'function snc:ent/pill/summon/5',
#  'function snc:ent/pill/vehicle/main',
#  'function snc:ent/pill/vehicle/spawn',
#  'function snc:ent/pill/vehicle/summon/willy',
#  'function snc:give/diary/peng',
#  'function snc:give/guide/love',
#  'function snc:give/guide/shifters',
#  'function snc:give/guide/shingeki',
#  'function snc:give/guide/shipload',
#  'function snc:give/guide/titan_war',
#  'function snc:give/guide/village',
#  'function snc:give/item/golden_mark',
#  'function snc:give/item/armor/atk_1',
#  'function snc:give/item/armor/atk_2',
#  'function snc:shifters/mobs/armor/abilities/give',
#  'function snc:give/item/armor/skull',
#  'function snc:give/item/attack/atk_1',
#  'function snc:give/item/attack/atk_2',
#  'function snc:give/item/attack/atk_3',
#  'function snc:give/item/attack/atk_4',
#  'function snc:shifters/mobs/attack/abilities/give',
#  'function snc:give/item/attack/skull',
#  'function snc:give/item/beast/atk_1',
#  'function snc:give/item/beast/atk_2',
#  'function snc:give/item/beast/atk_3',
#  'function snc:give/item/beast/atk_4',
#  'function snc:give/item/beast/atk_5',
#  'function snc:shifters/mobs/beast/abilities/give',
#  'function snc:give/item/cart/atk_3',
#  'function snc:give/item/cart/atk_5',
#  'function snc:give/item/cart/barrels',
#  'function snc:shifters/mobs/cart/abilities/give',
#  'function snc:give/item/cart/turrets',
#  'function snc:give/item/colossal/atk_1',
#  'function snc:give/item/colossal/atk_2',
#  'function snc:give/item/colossal/atk_4',
#  'function snc:shifters/mobs/colossal/abilities/give',
#  'function snc:give/item/drink/apple_juice',
#  'function snc:give/item/drink/beetroot_beer',
#  'function snc:give/item/drink/watermelon_juice',
#  'function snc:give/item/drink/wine',
#  'function snc:give/item/shifters/add_1',
#  'function snc:give/item/shifters/add_2',
#  'function snc:give/item/shifters/handcuffs',
#  'function snc:give/item/shifters/handcuffs_inv',
#  'function snc:give/item/shifters/needle',
#  'function snc:give/item/shifters/primary',
#  'function snc:give/item/shifters/shifters_finder',
#  'function snc:give/item/shifters/pure/eat',
#  'function snc:give/item/shifters/pure/jump',
#  'function snc:give/item/shifters/pure/main',
#  'function snc:give/item/shifters/pure/sprint',
#  'function snc:give/item/shifters/pure/stop',
#  'function snc:give/item/shifters/syringe/empty',
#  'function snc:give/item/shifters/syringe/full',
#  'function snc:give/item/shifters/syringe/royal',
#  'function snc:give/item/survey_corps/boots',
#  'function snc:give/item/survey_corps/cape',
#  'function snc:give/item/survey_corps/gas_trigger',
#  'function snc:give/item/survey_corps/harness',
#  'function snc:give/item/survey_corps/hood',
#  'function snc:give/item/survey_corps/odm_gear',
#  'function snc:give/item/survey_corps/blade/blade',
#  'function snc:give/item/survey_corps/blade/gas_trigger_blade',
#  'function snc:give/item/survey_corps/blade/odm_gear_blade',
#  'function snc:give/item/survey_corps/flare/black',
#  'function snc:give/item/survey_corps/flare/blank',
#  'function snc:give/item/survey_corps/flare/blue',
#  'function snc:give/item/survey_corps/flare/green',
#  'function snc:give/item/survey_corps/flare/purple',
#  'function snc:give/item/survey_corps/flare/red',
#  'function snc:give/item/survey_corps/flare/yellow',
#  'function snc:give/item/survey_corps/thunder/odm_sp2',
#  'function snc:give/item/survey_corps/thunder/odm_sp3',
#  'function snc:give/item/survey_corps/thunder/trigger_sp1',
#  'function snc:give/item/survey_corps/thunder/trigger_sp2',
#  'function snc:give/item/survey_corps/thunder/trigger_sp3',
#  'function snc:give/item/villager/invitation',
#  'function snc:give/item/villager/magus',
#  'function snc:give/item/villager/renamer',
#  'function snc:give/item/villager/sex',
#  'function snc:give/item/weapon/wrench',
#  'function snc:give/model/survey_corps/boots',
#  'function snc:give/model/survey_corps/cape',
#  'function snc:give/model/survey_corps/harness',
#  'function snc:give/model/survey_corps/hood',
#  'function snc:interact/main',
#  'function snc:interact/turret',
#  'function snc:interact/canon/aim',
#  'function snc:interact/canon/air',
#  'function snc:interact/canon/hit',
#  'function snc:interact/canon/land',
#  'function snc:interact/canon/remove',
#  'function snc:interact/canon/shoot',
#  'function snc:interact/canon/summon',
#  'function snc:interact/handcuffs/detect',
#  'function snc:interact/handcuffs/kill',
#  'function snc:interact/handcuffs/main',
#  'function snc:interact/handcuffs/remove',
#  'function snc:interact/handcuffs/reset',
#  'function snc:interact/handcuffs/select_human',
#  'function snc:interact/handcuffs/use',
#  'function snc:interact/handcuffs/add/player',
#  'function snc:interact/handcuffs/add/villager',
#  'function snc:item/main',
#  'function snc:item/debris/land',
#  'function snc:item/debris/main',
#  'function snc:item/return/atk_shifter',
#  'function snc:item/return/black',
#  'function snc:item/return/blue',
#  'function snc:item/return/green',
#  'function snc:item/return/purple',
#  'function snc:item/return/red',
#  'function snc:item/return/sex',
#  'function snc:item/return/yellow',
#  'function snc:logic/death',
#  'function snc:logic/disable',
#  'function snc:logic/distance',
#  'function snc:logic/hardcore',
#  'function snc:logic/kill_mob',
#  'function snc:logic/reset_kills',
#  'function snc:logic/return_gamemode',
#  'function snc:logic/advancements/1',
#  'function snc:logic/advancements/10',
#  'function snc:logic/advancements/100',
#  'function snc:logic/advancements/200',
#  'function snc:logic/advancements/25',
#  'function snc:logic/advancements/40',
#  'function snc:logic/advancements/70',
#  'function snc:logic/advancements/kill_count',
#  'function snc:logic/apply_motion/canon',
#  'function snc:logic/apply_motion/flare',
#  'function snc:logic/apply_motion/main',
#  'function snc:logic/apply_motion/odm',
#  'function snc:logic/apply_motion/player',
#  'function snc:logic/apply_motion/pure',
#  'function snc:logic/apply_motion/redirect_odm',
#  'function snc:logic/apply_motion/soldier',
#  'function snc:logic/apply_motion/spear',
#  'function snc:logic/apply_motion/titan_front',
#  'function snc:logic/apply_motion/turret',
#  'function snc:logic/apply_motion/vomit',
#  'function snc:logic/apply_motion/attack/main',
#  'function snc:logic/apply_motion/attack/punch_1',
#  'function snc:logic/apply_motion/attack/punch_up',
#  'function snc:logic/apply_motion/beast/main',
#  'function snc:logic/apply_motion/beast/throw_area',
#  'function snc:logic/apply_motion/beast/throw_big',
#  'function snc:logic/earthquake/move',
#  'function snc:logic/earthquake/score',
#  'function snc:logic/event/main',
#  'function snc:logic/event/start',
#  'function snc:logic/event/events/energy',
#  'function snc:logic/event/events/food',
#  'function snc:logic/event/events/marley',
#  'function snc:logic/event/events/raid',
#  'function snc:logic/event/events/seller',
#  'function snc:logic/event/events/sick',
#  'function snc:logic/event/events/taxes',
#  'function snc:logic/event/events/undying/1',
#  'function snc:logic/event/events/undying/2',
#  'function snc:logic/event/events/undying/main',
#  'function snc:logic/first/init',
#  'function snc:logic/first/main',
#  'function snc:logic/first/reload',
#  'function snc:logic/manual/config',
#  'function snc:logic/manual/init',
#  'function snc:logic/manual/trigger',
#  'function snc:logic/manual/off/anonymity',
#  'function snc:logic/manual/off/name_vill',
#  'function snc:logic/manual/off/send_command_feedback',
#  'function snc:logic/manual/off/show_kills',
#  'function snc:logic/manual/on/anonymity',
#  'function snc:logic/manual/on/name_vill',
#  'function snc:logic/manual/on/send_command_feedback',
#  'function snc:logic/manual/on/show_kills',
#  'function snc:logic/manual/on/vanilla_villagers',
#  'function snc:logic/manual/shifters/armor',
#  'function snc:logic/manual/shifters/attack',
#  'function snc:logic/manual/shifters/beast',
#  'function snc:logic/manual/shifters/cart',
#  'function snc:logic/manual/shifters/colossal',
#  'function snc:logic/push/back/1',
#  'function snc:logic/push/back/2',
#  'function snc:logic/push/back/3',
#  'function snc:logic/push/back/main',
#  'function snc:logic/quest/alex/adv',
#  'function snc:logic/quest/alex/main',
#  'function snc:logic/quest/alma/check_gift',
#  'function snc:logic/quest/alma/main',
#  'function snc:logic/quest/alma/summon',
#  'function snc:logic/quest/bob/main',
#  'function snc:logic/quest/bob/summon',
#  'function snc:logic/quest/bomb/adv',
#  'function snc:logic/quest/bomb/main',
#  'function snc:logic/quest/julian/check_gift',
#  'function snc:logic/quest/julian/main',
#  'function snc:logic/quest/julian/summon',
#  'function snc:logic/quest/niflum/adv',
#  'function snc:logic/quest/niflum/main',
#  'function snc:logic/quest/ragnaar/adv',
#  'function snc:logic/quest/ragnaar/main',
#  'function snc:logic/rotate/main',
#  'function snc:logic/rotate/180_91/112_91',
#  'function snc:logic/rotate/180_91/135_113',
#  'function snc:logic/rotate/180_91/157_136',
#  'function snc:logic/rotate/180_91/180_158',
#  'function snc:logic/rotate/180_91/main',
#  'function snc:logic/rotate/1_90/1_22',
#  'function snc:logic/rotate/1_90/23_45',
#  'function snc:logic/rotate/1_90/46_67',
#  'function snc:logic/rotate/1_90/68_90',
#  'function snc:logic/rotate/1_90/main',
#  'function snc:logic/rotate/90_1/22_1',
#  'function snc:logic/rotate/90_1/23_45',
#  'function snc:logic/rotate/90_1/67_46',
#  'function snc:logic/rotate/90_1/90_68',
#  'function snc:logic/rotate/90_1/main',
#  'function snc:logic/rotate/91_180/113_135',
#  'function snc:logic/rotate/91_180/136_157',
#  'function snc:logic/rotate/91_180/158_180',
#  'function snc:logic/rotate/91_180/91_112',
#  'function snc:logic/rotate/91_180/main',
#  'function snc:logic/schedule/5s',
#  'function snc:logic/schedule/15m/main',
#  'function snc:logic/schedule/15m/villager',
#  'function snc:logic/schedule/1h/main',
#  'function snc:logic/sticky/kill',
#  'function snc:logic/team/main',
#  'function snc:logic/team/revoke',
#  'function snc:logic/team/shifter',
#  'function snc:logic/team/survey_corps',
#  'function snc:player/drop_inv',
#  'function snc:player/main',
#  'function snc:player/messages',
#  'function snc:player/seconds_0',
#  'function snc:player/seconds_1',
#  'function snc:player/using_carrot',
#  'function snc:player/build/barrels',
#  'function snc:player/build/select_build',
#  'function snc:player/build/turrets',
#  'function snc:player/build/bell/desert',
#  'function snc:player/build/bell/enter',
#  'function snc:player/build/bell/forest',
#  'function snc:player/build/bell/found',
#  'function snc:player/build/bell/hill',
#  'function snc:player/build/bell/in',
#  'function snc:player/build/bell/plains',
#  'function snc:player/build/bell/select_biome',
#  'function snc:player/build/bell/spawn',
#  'function snc:player/build/bell/taiga',
#  'function snc:player/build/bell/village',
#  'function snc:player/build/bell/rename/false',
#  'function snc:player/build/bell/rename/main',
#  'function snc:player/build/bell/rename/true',
#  'function snc:player/build/cannon/east',
#  'function snc:player/build/cannon/north',
#  'function snc:player/build/cannon/south',
#  'function snc:player/build/cannon/west',
#  'function snc:player/build/stand/survey',
#  'function snc:player/build/stand/toy',
#  'function snc:player/gun/select_bullet',
#  'function snc:player/gun/select_effect',
#  'function snc:player/gun/select_gun',
#  'function snc:player/gun/flare/effect',
#  'function snc:player/gun/flare/select_color',
#  'function snc:player/gun/flare/shoot_black',
#  'function snc:player/gun/flare/shoot_blue',
#  'function snc:player/gun/flare/shoot_green',
#  'function snc:player/gun/flare/shoot_purple',
#  'function snc:player/gun/flare/shoot_red',
#  'function snc:player/gun/flare/shoot_yellow',
#  'function snc:player/gun/spear/air',
#  'function snc:player/gun/spear/effect',
#  'function snc:player/gun/spear/land',
#  'function snc:player/gun/spear/main',
#  'function snc:player/gun/spear/shoot',
#  'function snc:player/gun/spear/rot/1',
#  'function snc:player/gun/spear/rot/2',
#  'function snc:player/gun/spear/rot/3',
#  'function snc:player/gun/spear/rot/4',
#  'function snc:player/gun/spear/rot/5',
#  'function snc:player/gun/spear/rot/6',
#  'function snc:player/gun/spear/rot/7',
#  'function snc:player/gun/spear/rot/8',
#  'function snc:player/odm/break',
#  'function snc:player/odm/effects',
#  'function snc:player/odm/fall_damage',
#  'function snc:player/odm/has_trigger',
#  'function snc:player/odm/impulse',
#  'function snc:player/odm/main',
#  'function snc:player/odm/nape_impulse',
#  'function snc:player/odm/reset',
#  'function snc:player/odm/select_impulse',
#  'function snc:player/odm/select_range_kill',
#  'function snc:player/odm/select_slow_falling',
#  'function snc:player/odm/throw',
#  'function snc:player/odm/trigger_spear',
#  'function snc:player/odm/ground/bury',
#  'function snc:player/odm/ground/main',
#  'function snc:player/odm/ground/player_landed',
#  'function snc:player/odm/ground/select_players',
#  'function snc:player/odm/gyro/main',
#  'function snc:player/odm/gyro/select',
#  'function snc:player/odm/gyro/dash/1',
#  'function snc:player/odm/gyro/dash/2',
#  'function snc:player/odm/gyro/dash/3',
#  'function snc:player/odm/gyro/dash/4',
#  'function snc:player/odm/gyro/dash/5',
#  'function snc:player/odm/gyro/dash/6',
#  'function snc:player/odm/gyro/dash/main',
#  'function snc:player/odm/gyro/dash/odm_mini',
#  'function snc:player/odm/gyro/dash/reset',
#  'function snc:player/odm/impulse/get_direction',
#  'function snc:player/odm/replace_weapon/store_damage',
#  'function snc:player/odm/replace_weapon/store_left',
#  'function snc:player/odm/replace_weapon/store_right',
#  'function snc:player/odm/replace_weapon/thunder_sp2_effects',
#  'function snc:player/odm/replace_weapon/thunder_sp3_effects',
#  'function snc:player/odm/replace_weapon/get_blades/left/0',
#  'function snc:player/odm/replace_weapon/get_blades/left/10',
#  'function snc:player/odm/replace_weapon/get_blades/left/12',
#  'function snc:player/odm/replace_weapon/get_blades/left/15',
#  'function snc:player/odm/replace_weapon/get_blades/left/16',
#  'function snc:player/odm/replace_weapon/get_blades/left/18',
#  'function snc:player/odm/replace_weapon/get_blades/left/20',
#  'function snc:player/odm/replace_weapon/get_blades/left/25',
#  'function snc:player/odm/replace_weapon/get_blades/left/5',
#  'function snc:player/odm/replace_weapon/get_blades/left/6',
#  'function snc:player/odm/replace_weapon/get_blades/left/8',
#  'function snc:player/odm/replace_weapon/get_blades/left/main',
#  'function snc:player/odm/replace_weapon/get_blades/right/0',
#  'function snc:player/odm/replace_weapon/get_blades/right/10',
#  'function snc:player/odm/replace_weapon/get_blades/right/12',
#  'function snc:player/odm/replace_weapon/get_blades/right/15',
#  'function snc:player/odm/replace_weapon/get_blades/right/16',
#  'function snc:player/odm/replace_weapon/get_blades/right/18',
#  'function snc:player/odm/replace_weapon/get_blades/right/20',
#  'function snc:player/odm/replace_weapon/get_blades/right/25',
#  'function snc:player/odm/replace_weapon/get_blades/right/5',
#  'function snc:player/odm/replace_weapon/get_blades/right/6',
#  'function snc:player/odm/replace_weapon/get_blades/right/8',
#  'function snc:player/odm/replace_weapon/get_blades/right/main',
#  'function snc:player/odm/replace_weapon/get_spin/left/0',
#  'function snc:player/odm/replace_weapon/get_spin/left/10',
#  'function snc:player/odm/replace_weapon/get_spin/left/12',
#  'function snc:player/odm/replace_weapon/get_spin/left/15',
#  'function snc:player/odm/replace_weapon/get_spin/left/16',
#  'function snc:player/odm/replace_weapon/get_spin/left/18',
#  'function snc:player/odm/replace_weapon/get_spin/left/20',
#  'function snc:player/odm/replace_weapon/get_spin/left/5',
#  'function snc:player/odm/replace_weapon/get_spin/left/6',
#  'function snc:player/odm/replace_weapon/get_spin/left/8',
#  'function snc:player/odm/replace_weapon/get_spin/left/main',
#  'function snc:player/odm/replace_weapon/get_spin/right/0',
#  'function snc:player/odm/replace_weapon/get_spin/right/10',
#  'function snc:player/odm/replace_weapon/get_spin/right/12',
#  'function snc:player/odm/replace_weapon/get_spin/right/15',
#  'function snc:player/odm/replace_weapon/get_spin/right/16',
#  'function snc:player/odm/replace_weapon/get_spin/right/18',
#  'function snc:player/odm/replace_weapon/get_spin/right/20',
#  'function snc:player/odm/replace_weapon/get_spin/right/5',
#  'function snc:player/odm/replace_weapon/get_spin/right/6',
#  'function snc:player/odm/replace_weapon/get_spin/right/8',
#  'function snc:player/odm/replace_weapon/get_spin/right/main',
#  'function snc:player/odm/replace_weapon/get_thunder/left/100',
#  'function snc:player/odm/replace_weapon/get_thunder/left/33',
#  'function snc:player/odm/replace_weapon/get_thunder/left/66',
#  'function snc:player/odm/replace_weapon/get_thunder/left/main',
#  'function snc:player/odm/replace_weapon/get_thunder/right/16',
#  'function snc:player/odm/replace_weapon/get_thunder/right/25',
#  'function snc:player/odm/replace_weapon/get_thunder/right/8',
#  'function snc:player/odm/replace_weapon/get_thunder/right/main',
#  'function snc:player/odm/replace_weapon/leader/left',
#  'function snc:player/odm/replace_weapon/leader/main',
#  'function snc:player/odm/replace_weapon/leader/right',
#  'function snc:player/odm/replace_weapon/soldier/left',
#  'function snc:player/odm/replace_weapon/soldier/main',
#  'function snc:player/odm/replace_weapon/soldier/right',
#  'function snc:player/odm/replace_weapon/squad/left',
#  'function snc:player/odm/replace_weapon/squad/main',
#  'function snc:player/odm/replace_weapon/squad/right',
#  'function snc:player/odm/replace_weapon/veteran/left',
#  'function snc:player/odm/replace_weapon/veteran/main',
#  'function snc:player/odm/replace_weapon/veteran/right',
#  'function snc:player/titan/action',
#  'function snc:player/titan/blade',
#  'function snc:player/titan/kill',
#  'function snc:player/titan/main',
#  'function snc:player/titan/shifters_finder',
#  'function snc:player/titan/spear',
#  'function snc:player/titan/transformation',
#  'function snc:player/titan/effects/injured',
#  'function snc:player/titan/effects/pure',
#  'function snc:player/titan/infect/food',
#  'function snc:player/titan/infect/human',
#  'function snc:player/titan/infect/trigger',
#  'function snc:player/titan/injection/adv',
#  'function snc:player/titan/injection/check_villager',
#  'function snc:player/titan/injection/display',
#  'function snc:player/titan/injection/extract',
#  'function snc:player/titan/injection/failed',
#  'function snc:player/titan/injection/get',
#  'function snc:player/titan/injection/itself',
#  'function snc:player/titan/injection/main',
#  'function snc:player/titan/injection/normal',
#  'function snc:shifters/check',
#  'function snc:shifters/doesnt_exists',
#  'function snc:shifters/select_eldian',
#  'function snc:shifters/trigger',
#  'function snc:shifters/human/action',
#  'function snc:shifters/human/check_action',
#  'function snc:shifters/human/check_sneak',
#  'function snc:shifters/human/check_transform',
#  'function snc:shifters/human/check_untransform',
#  'function snc:shifters/human/main',
#  'function snc:shifters/human/regeneration',
#  'function snc:shifters/human/remove',
#  'function snc:shifters/human/revoke_adv',
#  'function snc:shifters/human/toggle_explosion',
#  'function snc:shifters/human/transform',
#  'function snc:shifters/human/untransform',
#  'function snc:shifters/human/explosion/boom',
#  'function snc:shifters/human/explosion/destroy',
#  'function snc:shifters/human/explosion/flash',
#  'function snc:shifters/human/explosion/kill',
#  'function snc:shifters/human/explosion/start',
#  'function snc:shifters/human/inventory/save',
#  'function snc:shifters/human/inventory/spawn',
#  'function snc:shifters/human/timer/cd',
#  'function snc:shifters/human/timer/cd_hurt',
#  'function snc:shifters/human/timer/display',
#  'function snc:shifters/human/timer/main',
#  'function snc:shifters/human/timer/time_down',
#  'function snc:shifters/mobs/apply_damage',
#  'function snc:shifters/mobs/arguments',
#  'function snc:shifters/mobs/check_dead',
#  'function snc:shifters/mobs/check_parry',
#  'function snc:shifters/mobs/check_shipload',
#  'function snc:shifters/mobs/collision',
#  'function snc:shifters/mobs/controller',
#  'function snc:shifters/mobs/curse',
#  'function snc:shifters/mobs/dead',
#  'function snc:shifters/mobs/floor',
#  'function snc:shifters/mobs/init',
#  'function snc:shifters/mobs/kill',
#  'function snc:shifters/mobs/kill_old',
#  'function snc:shifters/mobs/main',
#  'function snc:shifters/mobs/move',
#  'function snc:shifters/mobs/player',
#  'function snc:shifters/mobs/regeneration',
#  'function snc:shifters/mobs/roar',
#  'function snc:shifters/mobs/spawn',
#  'function snc:shifters/mobs/type',
#  'function snc:shifters/mobs/armor/curse',
#  'function snc:shifters/mobs/armor/hitbox',
#  'function snc:shifters/mobs/armor/model',
#  'function snc:shifters/mobs/armor/spawn',
#  'function snc:shifters/mobs/armor/animate/bite',
#  'function snc:shifters/mobs/armor/animate/block',
#  'function snc:shifters/mobs/armor/animate/born',
#  'function snc:shifters/mobs/armor/animate/death',
#  'function snc:shifters/mobs/armor/animate/grab',
#  'function snc:shifters/mobs/armor/animate/idle',
#  'function snc:shifters/mobs/armor/animate/init_charge',
#  'function snc:shifters/mobs/armor/animate/punch_1',
#  'function snc:shifters/mobs/armor/animate/punch_2',
#  'function snc:shifters/mobs/armor/animate/punch_3',
#  'function snc:shifters/mobs/armor/animate/roar',
#  'function snc:shifters/mobs/armor/animate/run',
#  'function snc:shifters/mobs/armor/animate/slide',
#  'function snc:shifters/mobs/armor/animate/sneak',
#  'function snc:shifters/mobs/armor/animate/walk',
#  'function snc:shifters/mobs/attack/curse',
#  'function snc:shifters/mobs/attack/hitbox',
#  'function snc:shifters/mobs/attack/model',
#  'function snc:shifters/mobs/attack/spawn',
#  'function snc:shifters/mobs/attack/animate/bite',
#  'function snc:shifters/mobs/attack/animate/block',
#  'function snc:shifters/mobs/attack/animate/born',
#  'function snc:shifters/mobs/attack/animate/death',
#  'function snc:shifters/mobs/attack/animate/grab',
#  'function snc:shifters/mobs/attack/animate/idle',
#  'function snc:shifters/mobs/attack/animate/kick_1',
#  'function snc:shifters/mobs/attack/animate/kick_2',
#  'function snc:shifters/mobs/attack/animate/kick_3',
#  'function snc:shifters/mobs/attack/animate/punch_1',
#  'function snc:shifters/mobs/attack/animate/punch_2',
#  'function snc:shifters/mobs/attack/animate/punch_3',
#  'function snc:shifters/mobs/attack/animate/roar',
#  'function snc:shifters/mobs/attack/animate/run',
#  'function snc:shifters/mobs/attack/animate/sneak',
#  'function snc:shifters/mobs/attack/animate/walk',
#  'function snc:shifters/mobs/beast/curse',
#  'function snc:shifters/mobs/beast/hitbox',
#  'function snc:shifters/mobs/beast/model',
#  'function snc:shifters/mobs/beast/spawn',
#  'function snc:shifters/mobs/beast/animate/bite',
#  'function snc:shifters/mobs/beast/animate/block',
#  'function snc:shifters/mobs/beast/animate/born',
#  'function snc:shifters/mobs/beast/animate/death',
#  'function snc:shifters/mobs/beast/animate/grab',
#  'function snc:shifters/mobs/beast/animate/idle',
#  'function snc:shifters/mobs/beast/animate/kick_1',
#  'function snc:shifters/mobs/beast/animate/kick_2',
#  'function snc:shifters/mobs/beast/animate/kick_3',
#  'function snc:shifters/mobs/beast/animate/roar',
#  'function snc:shifters/mobs/beast/animate/run',
#  'function snc:shifters/mobs/beast/animate/sneak',
#  'function snc:shifters/mobs/beast/animate/throw_area',
#  'function snc:shifters/mobs/beast/animate/throw_big',
#  'function snc:shifters/mobs/beast/animate/walk',
#  'function snc:shifters/mobs/cart/curse',
#  'function snc:shifters/mobs/cart/hitbox',
#  'function snc:shifters/mobs/cart/model',
#  'function snc:shifters/mobs/cart/spawn',
#  'function snc:shifters/mobs/cart/animate/bite',
#  'function snc:shifters/mobs/cart/animate/born',
#  'function snc:shifters/mobs/cart/animate/idle',
#  'function snc:shifters/mobs/cart/animate/roar',
#  'function snc:shifters/mobs/cart/animate/run',
#  'function snc:shifters/mobs/cart/animate/slam',
#  'function snc:shifters/mobs/cart/animate/sneak',
#  'function snc:shifters/mobs/cart/animate/stop_motion',
#  'function snc:shifters/mobs/cart/animate/walk',
#  'function snc:shifters/mobs/colossal/curse',
#  'function snc:shifters/mobs/colossal/hitbox',
#  'function snc:shifters/mobs/colossal/model',
#  'function snc:shifters/mobs/colossal/spawn',
#  'function snc:shifters/mobs/colossal/animate/bite',
#  'function snc:shifters/mobs/colossal/animate/born',
#  'function snc:shifters/mobs/colossal/animate/consume',
#  'function snc:shifters/mobs/colossal/animate/fall',
#  'function snc:shifters/mobs/colossal/animate/idle',
#  'function snc:shifters/mobs/colossal/animate/idle_wall',
#  'function snc:shifters/mobs/colossal/animate/roar',
#  'function snc:shifters/mobs/colossal/animate/run',
#  'function snc:shifters/mobs/colossal/animate/sneak',
#  'function snc:shifters/mobs/colossal/animate/steam',
#  'function snc:shifters/mobs/colossal/animate/stop_motion',
#  'function snc:shifters/mobs/colossal/animate/walk',
#  'function snc:shifters/mobs/colossal/animate/wallbreaker',
#  'function snc:shifters/sick/large',
#  'function snc:shifters/sick/normal',
#  'function snc:shifters/sick/short',
#  'function snc:shifters/transfer/actions',
#  'function snc:shifters/transfer/cheat',
#  'function snc:shifters/transfer/get',
#  'function snc:shifters/transfer/hit',
#  'function snc:shifters/transfer/lose',
#  'function snc:shifters/transfer/inherit/player',
#  'function snc:shifters/transfer/inherit/titan',
#  'function snc:shifters/transfer/inherit/villager',
#  'function snc:shifters/transfer/remove/player',
#  'function snc:shifters/transfer/remove/villager',
#  'function snc:titans/arguments',
#  'function snc:titans/c',
#  'function snc:titans/kill',
#  'function snc:titans/spawn/remove',
#  'function snc:titans/main',
#  'function snc:titans/remove_tags',
#  'function snc:titans/select_blood',
#  'function snc:titans/select_titan',
#  'function snc:titans/send_tags',
#  'function snc:titans/spawn',
#  'function snc:titans/spawn_wave',
#  'function snc:titans/trigger',
#  'function snc:titans/water',
#  'function snc:titans/ai/attack',
#  'function snc:titans/ai/damage_1',
#  'function snc:titans/ai/damage_2',
#  'function snc:titans/ai/despawn',
#  'function snc:titans/ai/detect',
#  'function snc:titans/ai/join_leader',
#  'function snc:titans/ai/jump',
#  'function snc:titans/ai/kill',
#  'function snc:titans/ai/koniglich',
#  'function snc:titans/ai/main',
#  'function snc:titans/ai/seconds',
#  'function snc:titans/ai/summon',
#  'function snc:titans/mobs/1/animate/attack',
#  'function snc:titans/mobs/1/animate/attack_2',
#  'function snc:titans/mobs/1/animate/idle',
#  'function snc:titans/mobs/1/animate/walk',
#  'function snc:titans/mobs/1/attack/1',
#  'function snc:titans/mobs/1/attack/2',
#  'function snc:titans/mobs/1/attack/main',
#  'function snc:titans/mobs/2/animate/attack',
#  'function snc:titans/mobs/2/animate/attack_2',
#  'function snc:titans/mobs/2/animate/idle',
#  'function snc:titans/mobs/2/animate/walk',
#  'function snc:titans/mobs/2/attack/1',
#  'function snc:titans/mobs/2/attack/2',
#  'function snc:titans/mobs/2/attack/main',
#  'function snc:titans/mobs/3/animate/attack',
#  'function snc:titans/mobs/3/animate/attack_2',
#  'function snc:titans/mobs/3/animate/idle',
#  'function snc:titans/mobs/3/animate/walk',
#  'function snc:titans/mobs/3/attack/1',
#  'function snc:titans/mobs/3/attack/2',
#  'function snc:titans/mobs/3/attack/main',
#  'function snc:titans/mobs/4/animate/attack',
#  'function snc:titans/mobs/4/animate/attack_2',
#  'function snc:titans/mobs/4/animate/idle',
#  'function snc:titans/mobs/4/animate/walk',
#  'function snc:titans/mobs/4/attack/1',
#  'function snc:titans/mobs/4/attack/2',
#  'function snc:titans/mobs/4/attack/main',
#  'function snc:titans/mobs/5/animate/attack',
#  'function snc:titans/mobs/5/animate/attack_2',
#  'function snc:titans/mobs/5/animate/idle',
#  'function snc:titans/mobs/5/animate/walk',
#  'function snc:titans/mobs/5/attack/1',
#  'function snc:titans/mobs/5/attack/2',
#  'function snc:titans/mobs/5/attack/main',
#  'function snc:titans/mobs/6/animate/attack',
#  'function snc:titans/mobs/6/animate/attack_2',
#  'function snc:titans/mobs/6/animate/idle',
#  'function snc:titans/mobs/6/animate/walk',
#  'function snc:titans/mobs/6/attack/1',
#  'function snc:titans/mobs/6/attack/2',
#  'function snc:titans/mobs/6/attack/main',
#  'function snc:titans/mobs/7/animate/idle',
#  'function snc:titans/mobs/7/animate/walk',
#  'function snc:titans/mobs/8/animate/attack',
#  'function snc:titans/mobs/8/animate/attack_2',
#  'function snc:titans/mobs/8/animate/idle',
#  'function snc:titans/mobs/8/animate/walk',
#  'function snc:titans/mobs/8/attack/1',
#  'function snc:titans/mobs/8/attack/2',
#  'function snc:titans/mobs/8/attack/main',
#  'function snc:titans/mobs/c/animate/idle',
#  'function snc:titans/mobs/c/animate/walk',
#  'function snc:titans/model/add_scores',
#  'function snc:titans/model/animate',
#  'function snc:titans/model/attack',
#  'function snc:titans/model/grab',
#  'function snc:titans/model/main',
#  'function snc:titans/tangible/collision',
#  'function snc:titans/tangible/hurtbox',
#  'function snc:titans/tangible/vomit/air',
#  'function snc:titans/tangible/vomit/land',
#  'function snc:titans/tangible/vomit/summon',
#  'function snc:titans/volt/change',
#  'function snc:titans/volt/joint',
#  'function snc:titans/volt/main',
#  'function snc:titans/volt/raycast',
#  'function snc:titans/volt/spawn',
#  'function snc:titans/volt/start']

# %%
# on this files
file_paths
# Out:
# ['../functions\\entity_tick.mcfunction',
#  '../functions\\load.mcfunction',
#  '../functions\\seconds.mcfunction',
#  '../functions\\test.mcfunction',
#  '../functions\\tick.mcfunction',
#  '../functions\\zzz_aux_functions.mcfunction',
#  '../functions\\api\\all_items.mcfunction',
#  '../functions\\api\\config.mcfunction',
#  '../functions\\api\\console_status.mcfunction',
#  '../functions\\api\\respawn_shifters.mcfunction',
#  '../functions\\api\\get\\royal_blood.mcfunction',
#  '../functions\\api\\get\\shifter\\armor.mcfunction',
#  '../functions\\api\\get\\shifter\\attack.mcfunction',
#  '../functions\\api\\get\\shifter\\beast.mcfunction',
#  '../functions\\api\\get\\shifter\\cart.mcfunction',
#  '../functions\\api\\get\\shifter\\colossal.mcfunction',
#  '../functions\\api\\get\\survey_corps\\blades.mcfunction',
#  '../functions\\api\\get\\survey_corps\\full.mcfunction',
#  '../functions\\api\\get\\survey_corps\\injection.mcfunction',
#  '../functions\\api\\get\\survey_corps\\rank\\0_soldier.mcfunction',
#  '../functions\\api\\get\\survey_corps\\rank\\1_veteran.mcfunction',
#  '../functions\\api\\get\\survey_corps\\rank\\2_team_leader.mcfunction',
#  '../functions\\api\\get\\survey_corps\\rank\\3_officer.mcfunction',
#  '../functions\\api\\get\\survey_corps\\rank\\4_squad.mcfunction',
#  '../functions\\api\\get\\survey_corps\\rank\\5_vice_captain.mcfunction',
#  '../functions\\api\\get\\survey_corps\\rank\\6_captain.mcfunction',
#  '../functions\\api\\summon\\titan\\1.mcfunction',
#  '../functions\\api\\summon\\titan\\2.mcfunction',
#  '../functions\\api\\summon\\titan\\3.mcfunction',
#  '../functions\\api\\summon\\titan\\4.mcfunction',
#  '../functions\\api\\summon\\titan\\5.mcfunction',
#  '../functions\\api\\summon\\titan\\6.mcfunction',
#  '../functions\\api\\summon\\titan\\7.mcfunction',
#  '../functions\\api\\summon\\titan\\8.mcfunction',
#  '../functions\\craft\\add_1.mcfunction',
#  '../functions\\craft\\blade.mcfunction',
#  '../functions\\craft\\boots.mcfunction',
#  '../functions\\craft\\cape.mcfunction',
#  '../functions\\craft\\gas_trigger.mcfunction',
#  '../functions\\craft\\gas_trigger_blade.mcfunction',
#  '../functions\\craft\\gas_trigger_sp1.mcfunction',
#  '../functions\\craft\\gas_trigger_sp2.mcfunction',
#  '../functions\\craft\\gas_trigger_sp3.mcfunction',
#  '../functions\\craft\\harness.mcfunction',
#  '../functions\\craft\\hood.mcfunction',
#  '../functions\\craft\\needle.mcfunction',
#  '../functions\\craft\\odm_gear.mcfunction',
#  '../functions\\craft\\odm_gear_blade.mcfunction',
#  '../functions\\craft\\odm_gear_sp2.mcfunction',
#  '../functions\\craft\\odm_gear_sp3.mcfunction',
#  '../functions\\craft\\shifters_finder.mcfunction',
#  '../functions\\craft\\wrench.mcfunction',
#  '../functions\\craft\\drink\\apple_juice.mcfunction',
#  '../functions\\craft\\drink\\beetroot_beer.mcfunction',
#  '../functions\\craft\\drink\\watermelon_juice.mcfunction',
#  '../functions\\craft\\drink\\wine.mcfunction',
#  '../functions\\craft\\flare\\black.mcfunction',
#  '../functions\\craft\\flare\\blank.mcfunction',
#  '../functions\\craft\\flare\\blue.mcfunction',
#  '../functions\\craft\\flare\\green.mcfunction',
#  '../functions\\craft\\flare\\purple.mcfunction',
#  '../functions\\craft\\flare\\red.mcfunction',
#  '../functions\\craft\\flare\\yellow.mcfunction',
#  '../functions\\craft\\shifters\\handcuffs.mcfunction',
#  '../functions\\craft\\shifters\\injection.mcfunction',
#  '../functions\\craft\\villager\\invitation.mcfunction',
#  '../functions\\craft\\villager\\renamer.mcfunction',
#  '../functions\\eldia\\add_follow.mcfunction',
#  '../functions\\eldia\\body.mcfunction',
#  '../functions\\eldia\\follow.mcfunction',
#  '../functions\\eldia\\koniglich.mcfunction',
#  '../functions\\eldia\\main.mcfunction',
#  '../functions\\eldia\\rem_follow.mcfunction',
#  '../functions\\eldia\\village.mcfunction',
#  '../functions\\eldia\\dialogue\\main.mcfunction',
#  '../functions\\eldia\\dialogue\\all\\busy.mcfunction',
#  '../functions\\eldia\\dialogue\\all\\energetic.mcfunction',
#  '../functions\\eldia\\dialogue\\all\\euphoric.mcfunction',
#  '../functions\\eldia\\dialogue\\all\\happy.mcfunction',
#  '../functions\\eldia\\dialogue\\all\\main.mcfunction',
#  '../functions\\eldia\\dialogue\\all\\timid.mcfunction',
#  '../functions\\eldia\\dialogue\\all\\wise.mcfunction',
#  '../functions\\eldia\\gene\\baby.mcfunction',
#  '../functions\\eldia\\gene\\bee.mcfunction',
#  '../functions\\eldia\\gene\\boy.mcfunction',
#  '../functions\\eldia\\gene\\check.mcfunction',
#  '../functions\\eldia\\gene\\check_partner.mcfunction',
#  '../functions\\eldia\\gene\\girl.mcfunction',
#  '../functions\\eldia\\gene\\partner.mcfunction',
#  '../functions\\eldia\\gene\\shifter.mcfunction',
#  '../functions\\eldia\\gene\\inherit\\main.mcfunction',
#  '../functions\\eldia\\gene\\inherit\\player\\main.mcfunction',
#  '../functions\\eldia\\gene\\inherit\\player\\man.mcfunction',
#  '../functions\\eldia\\gene\\inherit\\player\\woman\\main.mcfunction',
#  '../functions\\eldia\\gene\\inherit\\player\\woman\\royal.mcfunction',
#  '../functions\\eldia\\gene\\inherit\\villager\\main.mcfunction',
#  '../functions\\eldia\\gene\\inherit\\villager\\royal.mcfunction',
#  '../functions\\eldia\\respawn\\inherit.mcfunction',
#  '../functions\\eldia\\respawn\\inherit_fx.mcfunction',
#  '../functions\\eldia\\respawn\\main.mcfunction',
#  '../functions\\eldia\\respawn\\natural.mcfunction',
#  '../functions\\eldia\\villager\\awake.mcfunction',
#  '../functions\\eldia\\villager\\init.mcfunction',
#  '../functions\\eldia\\villager\\main.mcfunction',
#  '../functions\\eldia\\villager\\sleep.mcfunction',
#  '../functions\\eldia\\villager\\spawn.mcfunction',
#  '../functions\\eldia\\villager\\summon.mcfunction',
#  '../functions\\eldia\\villager\\summon_npc.mcfunction',
#  '../functions\\eldia\\villager\\model\\adult.mcfunction',
#  '../functions\\eldia\\villager\\model\\baby.mcfunction',
#  '../functions\\eldia\\villager\\model\\select.mcfunction',
#  '../functions\\eldia\\villager\\names\\female.mcfunction',
#  '../functions\\eldia\\villager\\names\\male.mcfunction',
#  '../functions\\eldia\\villager\\reputation\\check.mcfunction',
#  '../functions\\eldia\\villager\\reputation\\hit.mcfunction',
#  '../functions\\eldia\\villager\\reputation\\kill.mcfunction',
#  '../functions\\eldia\\villager\\reputation\\main.mcfunction',
#  '../functions\\eldia\\villager\\shifter\\armor.mcfunction',
#  '../functions\\eldia\\villager\\shifter\\attack.mcfunction',
#  '../functions\\eldia\\villager\\shifter\\beast.mcfunction',
#  '../functions\\eldia\\villager\\shifter\\cart.mcfunction',
#  '../functions\\eldia\\villager\\shifter\\colossal.mcfunction',
#  '../functions\\eldia\\villager\\shifter\\main.mcfunction',
#  '../functions\\eldia\\villager\\soldier\\attack.mcfunction',
#  '../functions\\eldia\\villager\\soldier\\main.mcfunction',
#  '../functions\\eldia\\villager\\soldier\\odm.mcfunction',
#  '../functions\\eldia\\villager\\summon\\ann.mcfunction',
#  '../functions\\eldia\\villager\\summon\\dave.mcfunction',
#  '../functions\\eldia\\villager\\summon\\emma.mcfunction',
#  '../functions\\eldia\\villager\\summon\\hannah.mcfunction',
#  '../functions\\eldia\\villager\\summon\\levin.mcfunction',
#  '../functions\\eldia\\villager\\summon\\marie.mcfunction',
#  '../functions\\eldia\\wandering_trader\\main.mcfunction',
#  '../functions\\eldia\\wandering_trader\\spawn.mcfunction',
#  '../functions\\eldia\\wandering_trader\\summon.mcfunction',
#  '../functions\\eldia\\wandering_trader\\summon\\alex.mcfunction',
#  '../functions\\eldia\\wandering_trader\\summon\\bomb.mcfunction',
#  '../functions\\eldia\\wandering_trader\\summon\\niflum.mcfunction',
#  '../functions\\eldia\\wandering_trader\\summon\\ragnaar.mcfunction',
#  '../functions\\eldia\\wandering_trader\\trades\\guide.mcfunction',
#  '../functions\\eldia\\wandering_trader\\trades\\main.mcfunction',
#  '../functions\\eldia\\wandering_trader\\trades\\mask.mcfunction',
#  '../functions\\eldia\\wandering_trader\\trades\\survey.mcfunction',
#  '../functions\\eldia\\wandering_trader\\trades\\toy.mcfunction',
#  '../functions\\ent\\disable_mobs.mcfunction',
#  '../functions\\ent\\human.mcfunction',
#  '../functions\\ent\\main.mcfunction',
#  '../functions\\ent\\seconds.mcfunction',
#  '../functions\\ent\\pill\\damage.mcfunction',
#  '../functions\\ent\\pill\\select_marleyan.mcfunction',
#  '../functions\\ent\\pill\\spawn_general.mcfunction',
#  '../functions\\ent\\pill\\spawn_soldier.mcfunction',
#  '../functions\\ent\\pill\\summon\\1.mcfunction',
#  '../functions\\ent\\pill\\summon\\5.mcfunction',
#  '../functions\\ent\\pill\\vehicle\\main.mcfunction',
#  '../functions\\ent\\pill\\vehicle\\spawn.mcfunction',
#  '../functions\\ent\\pill\\vehicle\\summon\\willy.mcfunction',
#  '../functions\\give\\diary\\peng.mcfunction',
#  '../functions\\give\\guide\\love.mcfunction',
#  '../functions\\give\\guide\\shifters.mcfunction',
#  '../functions\\give\\guide\\shingeki.mcfunction',
#  '../functions\\give\\guide\\shipload.mcfunction',
#  '../functions\\give\\guide\\titan_war.mcfunction',
#  '../functions\\give\\guide\\village.mcfunction',
#  '../functions\\give\\item\\golden_mark.mcfunction',
#  '../functions\\give\\item\\armor\\atk_1.mcfunction',
#  '../functions\\give\\item\\armor\\atk_2.mcfunction',
#  '../functions\\give\\item\\armor\\primary.mcfunction',
#  '../functions\\give\\item\\armor\\skull.mcfunction',
#  '../functions\\give\\item\\attack\\atk_1.mcfunction',
#  '../functions\\give\\item\\attack\\atk_2.mcfunction',
#  '../functions\\give\\item\\attack\\atk_3.mcfunction',
#  '../functions\\give\\item\\attack\\atk_4.mcfunction',
#  '../functions\\give\\item\\attack\\primary.mcfunction',
#  '../functions\\give\\item\\attack\\skull.mcfunction',
#  '../functions\\give\\item\\beast\\atk_1.mcfunction',
#  '../functions\\give\\item\\beast\\atk_2.mcfunction',
#  '../functions\\give\\item\\beast\\atk_3.mcfunction',
#  '../functions\\give\\item\\beast\\atk_4.mcfunction',
#  '../functions\\give\\item\\beast\\atk_5.mcfunction',
#  '../functions\\give\\item\\beast\\primary.mcfunction',
#  '../functions\\give\\item\\cart\\atk_3.mcfunction',
#  '../functions\\give\\item\\cart\\atk_5.mcfunction',
#  '../functions\\give\\item\\cart\\barrels.mcfunction',
#  '../functions\\give\\item\\cart\\primary.mcfunction',
#  '../functions\\give\\item\\cart\\turrets.mcfunction',
#  '../functions\\give\\item\\colossal\\atk_1.mcfunction',
#  '../functions\\give\\item\\colossal\\atk_2.mcfunction',
#  '../functions\\give\\item\\colossal\\atk_4.mcfunction',
#  '../functions\\give\\item\\colossal\\primary.mcfunction',
#  '../functions\\give\\item\\drink\\apple_juice.mcfunction',
#  '../functions\\give\\item\\drink\\beetroot_beer.mcfunction',
#  '../functions\\give\\item\\drink\\watermelon_juice.mcfunction',
#  '../functions\\give\\item\\drink\\wine.mcfunction',
#  '../functions\\give\\item\\shifters\\add_1.mcfunction',
#  '../functions\\give\\item\\shifters\\add_2.mcfunction',
#  '../functions\\give\\item\\shifters\\handcuffs.mcfunction',
#  '../functions\\give\\item\\shifters\\handcuffs_inv.mcfunction',
#  '../functions\\give\\item\\shifters\\needle.mcfunction',
#  '../functions\\give\\item\\shifters\\primary.mcfunction',
#  '../functions\\give\\item\\shifters\\shifters_finder.mcfunction',
#  '../functions\\give\\item\\shifters\\pure\\eat.mcfunction',
#  '../functions\\give\\item\\shifters\\pure\\jump.mcfunction',
#  '../functions\\give\\item\\shifters\\pure\\main.mcfunction',
#  '../functions\\give\\item\\shifters\\pure\\sprint.mcfunction',
#  '../functions\\give\\item\\shifters\\pure\\stop.mcfunction',
#  '../functions\\give\\item\\shifters\\syringe\\empty.mcfunction',
#  '../functions\\give\\item\\shifters\\syringe\\full.mcfunction',
#  '../functions\\give\\item\\shifters\\syringe\\royal.mcfunction',
#  '../functions\\give\\item\\survey_corps\\boots.mcfunction',
#  '../functions\\give\\item\\survey_corps\\cape.mcfunction',
#  '../functions\\give\\item\\survey_corps\\gas_trigger.mcfunction',
#  '../functions\\give\\item\\survey_corps\\harness.mcfunction',
#  '../functions\\give\\item\\survey_corps\\hood.mcfunction',
#  '../functions\\give\\item\\survey_corps\\odm_gear.mcfunction',
#  '../functions\\give\\item\\survey_corps\\blade\\blade.mcfunction',
#  '../functions\\give\\item\\survey_corps\\blade\\gas_trigger_blade.mcfunction',
#  '../functions\\give\\item\\survey_corps\\blade\\odm_gear_blade.mcfunction',
#  '../functions\\give\\item\\survey_corps\\flare\\black.mcfunction',
#  '../functions\\give\\item\\survey_corps\\flare\\blank.mcfunction',
#  '../functions\\give\\item\\survey_corps\\flare\\blue.mcfunction',
#  '../functions\\give\\item\\survey_corps\\flare\\green.mcfunction',
#  '../functions\\give\\item\\survey_corps\\flare\\purple.mcfunction',
#  '../functions\\give\\item\\survey_corps\\flare\\red.mcfunction',
#  '../functions\\give\\item\\survey_corps\\flare\\yellow.mcfunction',
#  '../functions\\give\\item\\survey_corps\\thunder\\odm_sp2.mcfunction',
#  '../functions\\give\\item\\survey_corps\\thunder\\odm_sp3.mcfunction',
#  '../functions\\give\\item\\survey_corps\\thunder\\trigger_sp1.mcfunction',
#  '../functions\\give\\item\\survey_corps\\thunder\\trigger_sp2.mcfunction',
#  '../functions\\give\\item\\survey_corps\\thunder\\trigger_sp3.mcfunction',
#  '../functions\\give\\item\\villager\\invitation.mcfunction',
#  '../functions\\give\\item\\villager\\magus.mcfunction',
#  '../functions\\give\\item\\villager\\renamer.mcfunction',
#  '../functions\\give\\item\\villager\\sex.mcfunction',
#  '../functions\\give\\item\\weapon\\wrench.mcfunction',
#  '../functions\\give\\model\\survey_corps\\boots.mcfunction',
#  '../functions\\give\\model\\survey_corps\\cape.mcfunction',
#  '../functions\\give\\model\\survey_corps\\harness.mcfunction',
#  '../functions\\give\\model\\survey_corps\\hood.mcfunction',
#  '../functions\\interact\\main.mcfunction',
#  '../functions\\interact\\turret.mcfunction',
#  '../functions\\interact\\canon\\aim.mcfunction',
#  '../functions\\interact\\canon\\air.mcfunction',
#  '../functions\\interact\\canon\\hit.mcfunction',
#  '../functions\\interact\\canon\\land.mcfunction',
#  '../functions\\interact\\canon\\remove.mcfunction',
#  '../functions\\interact\\canon\\shoot.mcfunction',
#  '../functions\\interact\\canon\\summon.mcfunction',
#  '../functions\\interact\\handcuffs\\detect.mcfunction',
#  '../functions\\interact\\handcuffs\\kill.mcfunction',
#  '../functions\\interact\\handcuffs\\main.mcfunction',
#  '../functions\\interact\\handcuffs\\remove.mcfunction',
#  '../functions\\interact\\handcuffs\\reset.mcfunction',
#  '../functions\\interact\\handcuffs\\select_human.mcfunction',
#  '../functions\\interact\\handcuffs\\use.mcfunction',
#  '../functions\\interact\\handcuffs\\add\\player.mcfunction',
#  '../functions\\interact\\handcuffs\\add\\villager.mcfunction',
#  '../functions\\item\\main.mcfunction',
#  '../functions\\item\\debris\\land.mcfunction',
#  '../functions\\item\\debris\\main.mcfunction',
#  '../functions\\item\\return\\atk_shifter.mcfunction',
#  '../functions\\item\\return\\black.mcfunction',
#  '../functions\\item\\return\\blue.mcfunction',
#  '../functions\\item\\return\\green.mcfunction',
#  '../functions\\item\\return\\purple.mcfunction',
#  '../functions\\item\\return\\red.mcfunction',
#  '../functions\\item\\return\\sex.mcfunction',
#  '../functions\\item\\return\\yellow.mcfunction',
#  '../functions\\logic\\death.mcfunction',
#  '../functions\\logic\\disable.mcfunction',
#  '../functions\\logic\\distance.mcfunction',
#  '../functions\\logic\\hardcore.mcfunction',
#  '../functions\\logic\\kill_mob.mcfunction',
#  '../functions\\logic\\reset_kills.mcfunction',
#  '../functions\\logic\\return_gamemode.mcfunction',
#  '../functions\\logic\\advancements\\1.mcfunction',
#  '../functions\\logic\\advancements\\10.mcfunction',
#  '../functions\\logic\\advancements\\100.mcfunction',
#  '../functions\\logic\\advancements\\200.mcfunction',
#  '../functions\\logic\\advancements\\25.mcfunction',
#  '../functions\\logic\\advancements\\40.mcfunction',
#  '../functions\\logic\\advancements\\70.mcfunction',
#  '../functions\\logic\\advancements\\kill_count.mcfunction',
#  '../functions\\logic\\apply_motion\\canon.mcfunction',
#  '../functions\\logic\\apply_motion\\flare.mcfunction',
#  '../functions\\logic\\apply_motion\\main.mcfunction',
#  '../functions\\logic\\apply_motion\\odm.mcfunction',
#  '../functions\\logic\\apply_motion\\player.mcfunction',
#  '../functions\\logic\\apply_motion\\pure.mcfunction',
#  '../functions\\logic\\apply_motion\\redirect_odm.mcfunction',
#  '../functions\\logic\\apply_motion\\soldier.mcfunction',
#  '../functions\\logic\\apply_motion\\spear.mcfunction',
#  '../functions\\logic\\apply_motion\\titan_front.mcfunction',
#  '../functions\\logic\\apply_motion\\turret.mcfunction',
#  '../functions\\logic\\apply_motion\\vomit.mcfunction',
#  '../functions\\logic\\apply_motion\\attack\\main.mcfunction',
#  '../functions\\logic\\apply_motion\\attack\\punch_1.mcfunction',
#  '../functions\\logic\\apply_motion\\attack\\punch_up.mcfunction',
#  '../functions\\logic\\apply_motion\\beast\\main.mcfunction',
#  '../functions\\logic\\apply_motion\\beast\\throw_area.mcfunction',
#  '../functions\\logic\\apply_motion\\beast\\throw_big.mcfunction',
#  '../functions\\logic\\earthquake\\move.mcfunction',
#  '../functions\\logic\\earthquake\\score.mcfunction',
#  '../functions\\logic\\event\\main.mcfunction',
#  '../functions\\logic\\event\\start.mcfunction',
#  '../functions\\logic\\event\\events\\energy.mcfunction',
#  '../functions\\logic\\event\\events\\food.mcfunction',
#  '../functions\\logic\\event\\events\\marley.mcfunction',
#  '../functions\\logic\\event\\events\\raid.mcfunction',
#  '../functions\\logic\\event\\events\\seller.mcfunction',
#  '../functions\\logic\\event\\events\\sick.mcfunction',
#  '../functions\\logic\\event\\events\\taxes.mcfunction',
#  '../functions\\logic\\event\\events\\undying\\1.mcfunction',
#  '../functions\\logic\\event\\events\\undying\\2.mcfunction',
#  '../functions\\logic\\event\\events\\undying\\main.mcfunction',
#  '../functions\\logic\\first\\init.mcfunction',
#  '../functions\\logic\\first\\main.mcfunction',
#  '../functions\\logic\\first\\reload.mcfunction',
#  '../functions\\logic\\manual\\config.mcfunction',
#  '../functions\\logic\\manual\\init.mcfunction',
#  '../functions\\logic\\manual\\trigger.mcfunction',
#  '../functions\\logic\\manual\\off\\anonymity.mcfunction',
#  '../functions\\logic\\manual\\off\\name_vill.mcfunction',
#  '../functions\\logic\\manual\\off\\send_command_feedback.mcfunction',
#  '../functions\\logic\\manual\\off\\show_kills.mcfunction',
#  '../functions\\logic\\manual\\on\\anonymity.mcfunction',
#  '../functions\\logic\\manual\\on\\name_vill.mcfunction',
#  '../functions\\logic\\manual\\on\\send_command_feedback.mcfunction',
#  '../functions\\logic\\manual\\on\\show_kills.mcfunction',
#  '../functions\\logic\\manual\\on\\vanilla_villagers.mcfunction',
#  '../functions\\logic\\manual\\shifters\\armor.mcfunction',
#  '../functions\\logic\\manual\\shifters\\attack.mcfunction',
#  '../functions\\logic\\manual\\shifters\\beast.mcfunction',
#  '../functions\\logic\\manual\\shifters\\cart.mcfunction',
#  '../functions\\logic\\manual\\shifters\\colossal.mcfunction',
#  '../functions\\logic\\push\\back\\1.mcfunction',
#  '../functions\\logic\\push\\back\\2.mcfunction',
#  '../functions\\logic\\push\\back\\3.mcfunction',
#  '../functions\\logic\\push\\back\\main.mcfunction',
#  '../functions\\logic\\quest\\alex\\adv.mcfunction',
#  '../functions\\logic\\quest\\alex\\main.mcfunction',
#  '../functions\\logic\\quest\\alma\\check_gift.mcfunction',
#  '../functions\\logic\\quest\\alma\\main.mcfunction',
#  '../functions\\logic\\quest\\alma\\summon.mcfunction',
#  '../functions\\logic\\quest\\bob\\main.mcfunction',
#  '../functions\\logic\\quest\\bob\\summon.mcfunction',
#  '../functions\\logic\\quest\\bomb\\adv.mcfunction',
#  '../functions\\logic\\quest\\bomb\\main.mcfunction',
#  '../functions\\logic\\quest\\julian\\check_gift.mcfunction',
#  '../functions\\logic\\quest\\julian\\main.mcfunction',
#  '../functions\\logic\\quest\\julian\\summon.mcfunction',
#  '../functions\\logic\\quest\\niflum\\adv.mcfunction',
#  '../functions\\logic\\quest\\niflum\\main.mcfunction',
#  '../functions\\logic\\quest\\ragnaar\\adv.mcfunction',
#  '../functions\\logic\\quest\\ragnaar\\main.mcfunction',
#  '../functions\\logic\\rotate\\main.mcfunction',
#  '../functions\\logic\\rotate\\180_91\\112_91.mcfunction',
#  '../functions\\logic\\rotate\\180_91\\135_113.mcfunction',
#  '../functions\\logic\\rotate\\180_91\\157_136.mcfunction',
#  '../functions\\logic\\rotate\\180_91\\180_158.mcfunction',
#  '../functions\\logic\\rotate\\180_91\\main.mcfunction',
#  '../functions\\logic\\rotate\\1_90\\1_22.mcfunction',
#  '../functions\\logic\\rotate\\1_90\\23_45.mcfunction',
#  '../functions\\logic\\rotate\\1_90\\46_67.mcfunction',
#  '../functions\\logic\\rotate\\1_90\\68_90.mcfunction',
#  '../functions\\logic\\rotate\\1_90\\main.mcfunction',
#  '../functions\\logic\\rotate\\90_1\\22_1.mcfunction',
#  '../functions\\logic\\rotate\\90_1\\23_45.mcfunction',
#  '../functions\\logic\\rotate\\90_1\\67_46.mcfunction',
#  '../functions\\logic\\rotate\\90_1\\90_68.mcfunction',
#  '../functions\\logic\\rotate\\90_1\\main.mcfunction',
#  '../functions\\logic\\rotate\\91_180\\113_135.mcfunction',
#  '../functions\\logic\\rotate\\91_180\\136_157.mcfunction',
#  '../functions\\logic\\rotate\\91_180\\158_180.mcfunction',
#  '../functions\\logic\\rotate\\91_180\\91_112.mcfunction',
#  '../functions\\logic\\rotate\\91_180\\main.mcfunction',
#  '../functions\\logic\\schedule\\5s.mcfunction',
#  '../functions\\logic\\schedule\\15m\\main.mcfunction',
#  '../functions\\logic\\schedule\\15m\\villager.mcfunction',
#  '../functions\\logic\\schedule\\1h\\main.mcfunction',
#  '../functions\\logic\\sticky\\kill.mcfunction',
#  '../functions\\logic\\team\\main.mcfunction',
#  '../functions\\logic\\team\\revoke.mcfunction',
#  '../functions\\logic\\team\\shifter.mcfunction',
#  '../functions\\logic\\team\\survey_corps.mcfunction',
#  '../functions\\player\\drop_inv.mcfunction',
#  '../functions\\player\\main.mcfunction',
#  '../functions\\player\\messages.mcfunction',
#  '../functions\\player\\seconds_0.mcfunction',
#  '../functions\\player\\seconds_1.mcfunction',
#  '../functions\\player\\using_carrot.mcfunction',
#  '../functions\\player\\build\\barrels.mcfunction',
#  '../functions\\player\\build\\select_build.mcfunction',
#  '../functions\\player\\build\\turrets.mcfunction',
#  '../functions\\player\\build\\bell\\desert.mcfunction',
#  '../functions\\player\\build\\bell\\enter.mcfunction',
#  '../functions\\player\\build\\bell\\forest.mcfunction',
#  '../functions\\player\\build\\bell\\found.mcfunction',
#  '../functions\\player\\build\\bell\\hill.mcfunction',
#  '../functions\\player\\build\\bell\\in.mcfunction',
#  '../functions\\player\\build\\bell\\plains.mcfunction',
#  '../functions\\player\\build\\bell\\select_biome.mcfunction',
#  '../functions\\player\\build\\bell\\spawn.mcfunction',
#  '../functions\\player\\build\\bell\\taiga.mcfunction',
#  '../functions\\player\\build\\bell\\village.mcfunction',
#  '../functions\\player\\build\\bell\\rename\\false.mcfunction',
#  '../functions\\player\\build\\bell\\rename\\main.mcfunction',
#  '../functions\\player\\build\\bell\\rename\\true.mcfunction',
#  '../functions\\player\\build\\cannon\\east.mcfunction',
#  '../functions\\player\\build\\cannon\\north.mcfunction',
#  '../functions\\player\\build\\cannon\\south.mcfunction',
#  '../functions\\player\\build\\cannon\\west.mcfunction',
#  '../functions\\player\\build\\stand\\survey.mcfunction',
#  '../functions\\player\\build\\stand\\toy.mcfunction',
#  '../functions\\player\\gun\\select_bullet.mcfunction',
#  '../functions\\player\\gun\\select_effect.mcfunction',
#  '../functions\\player\\gun\\select_gun.mcfunction',
#  '../functions\\player\\gun\\flare\\effect.mcfunction',
#  '../functions\\player\\gun\\flare\\select_color.mcfunction',
#  '../functions\\player\\gun\\flare\\shoot_black.mcfunction',
#  '../functions\\player\\gun\\flare\\shoot_blue.mcfunction',
#  '../functions\\player\\gun\\flare\\shoot_green.mcfunction',
#  '../functions\\player\\gun\\flare\\shoot_purple.mcfunction',
#  '../functions\\player\\gun\\flare\\shoot_red.mcfunction',
#  '../functions\\player\\gun\\flare\\shoot_yellow.mcfunction',
#  '../functions\\player\\gun\\spear\\air.mcfunction',
#  '../functions\\player\\gun\\spear\\effect.mcfunction',
#  '../functions\\player\\gun\\spear\\land.mcfunction',
#  '../functions\\player\\gun\\spear\\main.mcfunction',
#  '../functions\\player\\gun\\spear\\shoot.mcfunction',
#  '../functions\\player\\gun\\spear\\rot\\1.mcfunction',
#  '../functions\\player\\gun\\spear\\rot\\2.mcfunction',
#  '../functions\\player\\gun\\spear\\rot\\3.mcfunction',
#  '../functions\\player\\gun\\spear\\rot\\4.mcfunction',
#  '../functions\\player\\gun\\spear\\rot\\5.mcfunction',
#  '../functions\\player\\gun\\spear\\rot\\6.mcfunction',
#  '../functions\\player\\gun\\spear\\rot\\7.mcfunction',
#  '../functions\\player\\gun\\spear\\rot\\8.mcfunction',
#  '../functions\\player\\odm\\break.mcfunction',
#  '../functions\\player\\odm\\effects.mcfunction',
#  '../functions\\player\\odm\\fall_damage.mcfunction',
#  '../functions\\player\\odm\\has_trigger.mcfunction',
#  '../functions\\player\\odm\\impulse.mcfunction',
#  '../functions\\player\\odm\\main.mcfunction',
#  '../functions\\player\\odm\\nape_impulse.mcfunction',
#  '../functions\\player\\odm\\reset.mcfunction',
#  '../functions\\player\\odm\\select_impulse.mcfunction',
#  '../functions\\player\\odm\\select_range_kill.mcfunction',
#  '../functions\\player\\odm\\select_slow_falling.mcfunction',
#  '../functions\\player\\odm\\throw.mcfunction',
#  '../functions\\player\\odm\\trigger_spear.mcfunction',
#  '../functions\\player\\odm\\ground\\bury.mcfunction',
#  '../functions\\player\\odm\\ground\\main.mcfunction',
#  '../functions\\player\\odm\\ground\\player_landed.mcfunction',
#  '../functions\\player\\odm\\ground\\select_players.mcfunction',
#  '../functions\\player\\odm\\gyro\\main.mcfunction',
#  '../functions\\player\\odm\\gyro\\select.mcfunction',
#  '../functions\\player\\odm\\gyro/dash\\1.mcfunction',
#  '../functions\\player\\odm\\gyro/dash\\2.mcfunction',
#  '../functions\\player\\odm\\gyro/dash\\3.mcfunction',
#  '../functions\\player\\odm\\gyro/dash\\4.mcfunction',
#  '../functions\\player\\odm\\gyro/dash\\5.mcfunction',
#  '../functions\\player\\odm\\gyro/dash\\6.mcfunction',
#  '../functions\\player\\odm\\gyro/dash\\main.mcfunction',
#  '../functions\\player\\odm\\gyro/dash\\odm_mini.mcfunction',
#  '../functions\\player\\odm\\gyro/dash\\reset.mcfunction',
#  '../functions\\player\\odm\\impulse\\get_direction.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\store_damage.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\store_left.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\store_right.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\thunder_sp2_effects.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\thunder_sp3_effects.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\left\\0.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\left\\10.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\left\\12.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\left\\15.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\left\\16.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\left\\18.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\left\\20.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\left\\25.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\left\\5.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\left\\6.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\left\\8.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\left\\main.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\right\\0.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\right\\10.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\right\\12.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\right\\15.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\right\\16.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\right\\18.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\right\\20.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\right\\25.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\right\\5.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\right\\6.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\right\\8.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_blades\\right\\main.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\left\\0.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\left\\10.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\left\\12.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\left\\15.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\left\\16.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\left\\18.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\left\\20.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\left\\5.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\left\\6.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\left\\8.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\left\\main.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\right\\0.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\right\\10.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\right\\12.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\right\\15.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\right\\16.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\right\\18.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\right\\20.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\right\\5.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\right\\6.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\right\\8.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_spin\\right\\main.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_thunder\\left\\100.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_thunder\\left\\33.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_thunder\\left\\66.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_thunder\\left\\main.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_thunder\\right\\16.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_thunder\\right\\25.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_thunder\\right\\8.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\get_thunder\\right\\main.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\leader\\left.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\leader\\main.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\leader\\right.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\soldier\\left.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\soldier\\main.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\soldier\\right.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\squad\\left.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\squad\\main.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\squad\\right.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\veteran\\left.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\veteran\\main.mcfunction',
#  '../functions\\player\\odm\\replace_weapon\\veteran\\right.mcfunction',
#  '../functions\\player\\titan\\action.mcfunction',
#  '../functions\\player\\titan\\blade.mcfunction',
#  '../functions\\player\\titan\\kill.mcfunction',
#  '../functions\\player\\titan\\main.mcfunction',
#  '../functions\\player\\titan\\shifters_finder.mcfunction',
#  '../functions\\player\\titan\\spear.mcfunction',
#  '../functions\\player\\titan\\transformation.mcfunction',
#  '../functions\\player\\titan\\effects\\injured.mcfunction',
#  '../functions\\player\\titan\\effects\\pure.mcfunction',
#  '../functions\\player\\titan\\infect\\food.mcfunction',
#  '../functions\\player\\titan\\infect\\human.mcfunction',
#  '../functions\\player\\titan\\infect\\trigger.mcfunction',
#  '../functions\\player\\titan\\injection\\adv.mcfunction',
#  '../functions\\player\\titan\\injection\\check_villager.mcfunction',
#  '../functions\\player\\titan\\injection\\display.mcfunction',
#  '../functions\\player\\titan\\injection\\extract.mcfunction',
#  '../functions\\player\\titan\\injection\\failed.mcfunction',
#  '../functions\\player\\titan\\injection\\get.mcfunction',
#  '../functions\\player\\titan\\injection\\itself.mcfunction',
#  '../functions\\player\\titan\\injection\\main.mcfunction',
#  '../functions\\player\\titan\\injection\\normal.mcfunction',
#  '../functions\\shifters\\check.mcfunction',
#  '../functions\\shifters\\doesnt_exists.mcfunction',
#  '../functions\\shifters\\select_eldian.mcfunction',
#  '../functions\\shifters\\trigger.mcfunction',
#  '../functions\\shifters\\human\\action.mcfunction',
#  '../functions\\shifters\\human\\check_action.mcfunction',
#  '../functions\\shifters\\human\\check_sneak.mcfunction',
#  '../functions\\shifters\\human\\check_transform.mcfunction',
#  '../functions\\shifters\\human\\check_untransform.mcfunction',
#  '../functions\\shifters\\human\\main.mcfunction',
#  '../functions\\shifters\\human\\regeneration.mcfunction',
#  '../functions\\shifters\\human\\remove.mcfunction',
#  '../functions\\shifters\\human\\revoke_adv.mcfunction',
#  '../functions\\shifters\\human\\toggle_explosion.mcfunction',
#  '../functions\\shifters\\human\\transform.mcfunction',
#  '../functions\\shifters\\human\\untransform.mcfunction',
#  '../functions\\shifters\\human\\explosion\\boom.mcfunction',
#  '../functions\\shifters\\human\\explosion\\destroy.mcfunction',
#  '../functions\\shifters\\human\\explosion\\flash.mcfunction',
#  '../functions\\shifters\\human\\explosion\\kill.mcfunction',
#  '../functions\\shifters\\human\\explosion\\start.mcfunction',
#  '../functions\\shifters\\human\\inventory\\save.mcfunction',
#  '../functions\\shifters\\human\\inventory\\spawn.mcfunction',
#  '../functions\\shifters\\human\\timer\\cd.mcfunction',
#  '../functions\\shifters\\human\\timer\\cd_hurt.mcfunction',
#  '../functions\\shifters\\human\\timer\\display.mcfunction',
#  '../functions\\shifters\\human\\timer\\main.mcfunction',
#  '../functions\\shifters\\human\\timer\\time_down.mcfunction',
#  '../functions\\shifters\\mobs\\apply_damage.mcfunction',
#  '../functions\\shifters\\mobs\\arguments.mcfunction',
#  '../functions\\shifters\\mobs\\check_dead.mcfunction',
#  '../functions\\shifters\\mobs\\check_parry.mcfunction',
#  '../functions\\shifters\\mobs\\check_shipload.mcfunction',
#  '../functions\\shifters\\mobs\\collision.mcfunction',
#  '../functions\\shifters\\mobs\\controller.mcfunction',
#  '../functions\\shifters\\mobs\\curse.mcfunction',
#  '../functions\\shifters\\mobs\\dead.mcfunction',
#  '../functions\\shifters\\mobs\\floor.mcfunction',
#  '../functions\\shifters\\mobs\\init.mcfunction',
#  '../functions\\shifters\\mobs\\kill.mcfunction',
#  '../functions\\shifters\\mobs\\kill_old.mcfunction',
#  '../functions\\shifters\\mobs\\main.mcfunction',
#  '../functions\\shifters\\mobs\\move.mcfunction',
#  '../functions\\shifters\\mobs\\player.mcfunction',
#  '../functions\\shifters\\mobs\\regeneration.mcfunction',
#  '../functions\\shifters\\mobs\\roar.mcfunction',
#  '../functions\\shifters\\mobs\\spawn.mcfunction',
#  '../functions\\shifters\\mobs\\type.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\curse.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\hitbox.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\model.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\spawn.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\born\\1.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\born\\10.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\born\\11.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\born\\12.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\born\\13.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\born\\14.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\born\\2.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\born\\3.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\born\\4.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\born\\5.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\born\\6.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\born\\7.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\born\\8.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\born\\9.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\charge\\angle.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\charge\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\charge\\end.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\charge\\init.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\charge\\prepare.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\charge\\slide.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\charge\\wind.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\death\\corpse.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\death\\decay.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\death\\fall.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\jaw\\add_tags.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\jaw\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\jaw\\tp.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\movement\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\movement\\step.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\punch_1\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\punch_1\\direction.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\punch_1\\end.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\punch_1\\impulse.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\punch_2\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\punch_2\\direction.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\punch_2\\end.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\punch_2\\impulse.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\punch_3\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\punch_3\\direction.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\punch_3\\end.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\action\\punch_3\\impulse.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\animate\\bite.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\animate\\block.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\animate\\born.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\animate\\death.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\animate\\grab.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\animate\\idle.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\animate\\init_charge.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\animate\\punch_1.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\animate\\punch_2.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\animate\\punch_3.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\animate\\roar.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\animate\\run.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\animate\\slide.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\animate\\sneak.mcfunction',
#  '../functions\\shifters\\mobs\\armor\\animate\\walk.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\curse.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\hitbox.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\model.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\spawn.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\koniglich.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\block\\end.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\block\\hurt.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\born\\1.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\born\\10.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\born\\11.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\born\\12.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\born\\13.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\born\\14.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\born\\2.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\born\\3.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\born\\4.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\born\\5.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\born\\6.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\born\\7.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\born\\8.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\born\\9.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\death\\corpse.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\death\\decay.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\death\\fall.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\jaw\\add_tags.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\jaw\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\jaw\\tp.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\kick_1\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\kick_1\\direction.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\kick_1\\end.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\kick_1\\impulse.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\kick_2\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\kick_2\\direction.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\kick_2\\end.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\kick_2\\impulse.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\kick_3\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\kick_3\\end.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\kick_3\\impulse.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\movement\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\movement\\step.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\punch_1\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\punch_1\\direction.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\punch_1\\end.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\punch_1\\impulse.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\punch_2\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\punch_2\\direction.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\punch_2\\end.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\punch_2\\impulse.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\punch_3\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\punch_3\\direction.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\punch_3\\end.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\action\\punch_3\\impulse.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\animate\\bite.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\animate\\block.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\animate\\born.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\animate\\death.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\animate\\grab.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\animate\\idle.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\animate\\kick_1.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\animate\\kick_2.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\animate\\kick_3.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\animate\\punch_1.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\animate\\punch_2.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\animate\\punch_3.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\animate\\roar.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\animate\\run.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\animate\\sneak.mcfunction',
#  '../functions\\shifters\\mobs\\attack\\animate\\walk.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\curse.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\hitbox.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\model.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\spawn.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\block\\end.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\block\\hurt.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\born\\1.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\born\\10.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\born\\11.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\born\\12.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\born\\13.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\born\\14.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\born\\15.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\born\\16.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\born\\17.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\born\\18.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\born\\2.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\born\\3.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\born\\4.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\born\\5.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\born\\6.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\born\\7.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\born\\8.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\born\\9.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\death\\corpse.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\death\\decay.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\death\\fall.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\grab\\disable.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\grab\\dismount.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\grab\\enable.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\grab\\end.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\grab\\highlight.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\grab\\pivot.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\grab\\ready.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\grab\\ride.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\jaw\\add_tags.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\jaw\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\jaw\\tp.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\movement\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\movement\\step.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\sense\\particle.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\throw_area\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\throw_area\\dismount.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\throw_area\\end.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\throw_area\\impulse.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\throw_area\\levitate.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\throw_area\\prepare.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\throw_area\\rock.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\throw_big\\crash.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\throw_big\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\throw_big\\direction.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\throw_big\\end.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\throw_big\\impulse.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\throw_big\\impulse_aux.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\throw_big\\kill.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\throw_big\\levitate.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\throw_big\\prepare.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\throw_big\\rock.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\action\\throw_big\\summon.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\animate\\bite.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\animate\\block.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\animate\\born.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\animate\\death.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\animate\\grab.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\animate\\idle.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\animate\\kick_1.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\animate\\kick_2.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\animate\\kick_3.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\animate\\roar.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\animate\\run.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\animate\\sneak.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\animate\\throw_area.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\animate\\throw_big.mcfunction',
#  '../functions\\shifters\\mobs\\beast\\animate\\walk.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\curse.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\hitbox.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\model.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\spawn.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\born\\1.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\born\\10.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\born\\11.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\born\\12.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\born\\13.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\born\\14.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\born\\2.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\born\\3.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\born\\4.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\born\\5.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\born\\6.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\born\\7.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\born\\8.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\born\\9.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\death\\corpse.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\death\\decay.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\death\\fall.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\jaw\\bite.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\jaw\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\jaw\\init.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\jaw\\roar.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\movement\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\movement\\sneak.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\movement\\step.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\shipload\\module.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\shipload\\barrels\\drop.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\shipload\\barrels\\spawn.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\shipload\\turrets\\main.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\shipload\\turrets\\shoot.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\shipload\\turrets\\spawn.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\slam\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\action\\slam\\init.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\animate\\bite.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\animate\\born.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\animate\\idle.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\animate\\roar.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\animate\\run.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\animate\\slam.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\animate\\sneak.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\animate\\stop_motion.mcfunction',
#  '../functions\\shifters\\mobs\\cart\\animate\\walk.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\curse.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\hitbox.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\model.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\spawn.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\born\\1.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\born\\10.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\born\\11.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\born\\12.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\born\\13.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\born\\14.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\born\\2.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\born\\3.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\born\\4.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\born\\5.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\born\\6.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\born\\7.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\born\\8.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\born\\9.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\death\\corpse.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\death\\decay.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\death\\fall.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\explosion\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\explosion\\kill.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\explosion\\main.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\explosion\\spawn.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\footstep\\1.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\footstep\\2.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\footstep\\3.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\footstep\\4.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\footstep\\5.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\jaw\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\jaw\\init.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\jaw\\roar.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\jaw\\tp.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\movement\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\movement\\height.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\movement\\legs_height.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\movement\\step.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\steam\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\steam\\init.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\wallbreaker\\damage.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\wallbreaker\\dmg_entities.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\wallbreaker\\init.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\wallbreaker\\fill\\1.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\wallbreaker\\fill\\2.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\wallbreaker\\fill\\3.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\wallbreaker\\fill\\4.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\action\\wallbreaker\\fill\\5.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\animate\\bite.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\animate\\born.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\animate\\consume.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\animate\\fall.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\animate\\idle.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\animate\\idle_wall.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\animate\\roar.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\animate\\run.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\animate\\sneak.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\animate\\steam.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\animate\\stop_motion.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\animate\\walk.mcfunction',
#  '../functions\\shifters\\mobs\\colossal\\animate\\wallbreaker.mcfunction',
#  '../functions\\shifters\\sick\\large.mcfunction',
#  '../functions\\shifters\\sick\\normal.mcfunction',
#  '../functions\\shifters\\sick\\short.mcfunction',
#  '../functions\\shifters\\transfer\\actions.mcfunction',
#  '../functions\\shifters\\transfer\\cheat.mcfunction',
#  '../functions\\shifters\\transfer\\get.mcfunction',
#  '../functions\\shifters\\transfer\\hit.mcfunction',
#  '../functions\\shifters\\transfer\\lose.mcfunction',
#  '../functions\\shifters\\transfer\\inherit\\player.mcfunction',
#  '../functions\\shifters\\transfer\\inherit\\titan.mcfunction',
#  '../functions\\shifters\\transfer\\inherit\\villager.mcfunction',
#  '../functions\\shifters\\transfer\\remove\\player.mcfunction',
#  '../functions\\shifters\\transfer\\remove\\villager.mcfunction',
#  '../functions\\titans\\arguments.mcfunction',
#  '../functions\\titans\\c.mcfunction',
#  '../functions\\titans\\kill.mcfunction',
#  '../functions\\titans\\kill_spawn.mcfunction',
#  '../functions\\titans\\main.mcfunction',
#  '../functions\\titans\\remove_tags.mcfunction',
#  '../functions\\titans\\select_blood.mcfunction',
#  '../functions\\titans\\select_titan.mcfunction',
#  '../functions\\titans\\send_tags.mcfunction',
#  '../functions\\titans\\spawn.mcfunction',
#  '../functions\\titans\\spawn_wave.mcfunction',
#  '../functions\\titans\\trigger.mcfunction',
#  '../functions\\titans\\water.mcfunction',
#  '../functions\\titans\\ai\\attack.mcfunction',
#  '../functions\\titans\\ai\\damage_1.mcfunction',
#  '../functions\\titans\\ai\\damage_2.mcfunction',
#  '../functions\\titans\\ai\\despawn.mcfunction',
#  '../functions\\titans\\ai\\detect.mcfunction',
#  '../functions\\titans\\ai\\join_leader.mcfunction',
#  '../functions\\titans\\ai\\jump.mcfunction',
#  '../functions\\titans\\ai\\kill.mcfunction',
#  '../functions\\titans\\ai\\koniglich.mcfunction',
#  '../functions\\titans\\ai\\main.mcfunction',
#  '../functions\\titans\\ai\\seconds.mcfunction',
#  '../functions\\titans\\ai\\summon.mcfunction',
#  '../functions\\titans\\mobs\\1\\animate\\attack.mcfunction',
#  '../functions\\titans\\mobs\\1\\animate\\attack_2.mcfunction',
#  '../functions\\titans\\mobs\\1\\animate\\idle.mcfunction',
#  '../functions\\titans\\mobs\\1\\animate\\walk.mcfunction',
#  '../functions\\titans\\mobs\\1\\attack\\1.mcfunction',
#  '../functions\\titans\\mobs\\1\\attack\\2.mcfunction',
#  '../functions\\titans\\mobs\\1\\attack\\main.mcfunction',
#  '../functions\\titans\\mobs\\2\\animate\\attack.mcfunction',
#  '../functions\\titans\\mobs\\2\\animate\\attack_2.mcfunction',
#  '../functions\\titans\\mobs\\2\\animate\\idle.mcfunction',
#  '../functions\\titans\\mobs\\2\\animate\\walk.mcfunction',
#  '../functions\\titans\\mobs\\2\\attack\\1.mcfunction',
#  '../functions\\titans\\mobs\\2\\attack\\2.mcfunction',
#  '../functions\\titans\\mobs\\2\\attack\\main.mcfunction',
#  '../functions\\titans\\mobs\\3\\animate\\attack.mcfunction',
#  '../functions\\titans\\mobs\\3\\animate\\attack_2.mcfunction',
#  '../functions\\titans\\mobs\\3\\animate\\idle.mcfunction',
#  '../functions\\titans\\mobs\\3\\animate\\walk.mcfunction',
#  '../functions\\titans\\mobs\\3\\attack\\1.mcfunction',
#  '../functions\\titans\\mobs\\3\\attack\\2.mcfunction',
#  '../functions\\titans\\mobs\\3\\attack\\main.mcfunction',
#  '../functions\\titans\\mobs\\4\\animate\\attack.mcfunction',
#  '../functions\\titans\\mobs\\4\\animate\\attack_2.mcfunction',
#  '../functions\\titans\\mobs\\4\\animate\\idle.mcfunction',
#  '../functions\\titans\\mobs\\4\\animate\\walk.mcfunction',
#  '../functions\\titans\\mobs\\4\\attack\\1.mcfunction',
#  '../functions\\titans\\mobs\\4\\attack\\2.mcfunction',
#  '../functions\\titans\\mobs\\4\\attack\\main.mcfunction',
#  '../functions\\titans\\mobs\\5\\animate\\attack.mcfunction',
#  '../functions\\titans\\mobs\\5\\animate\\attack_2.mcfunction',
#  '../functions\\titans\\mobs\\5\\animate\\idle.mcfunction',
#  '../functions\\titans\\mobs\\5\\animate\\walk.mcfunction',
#  '../functions\\titans\\mobs\\5\\attack\\1.mcfunction',
#  '../functions\\titans\\mobs\\5\\attack\\2.mcfunction',
#  '../functions\\titans\\mobs\\5\\attack\\main.mcfunction',
#  '../functions\\titans\\mobs\\6\\animate\\attack.mcfunction',
#  '../functions\\titans\\mobs\\6\\animate\\attack_2.mcfunction',
#  '../functions\\titans\\mobs\\6\\animate\\idle.mcfunction',
#  '../functions\\titans\\mobs\\6\\animate\\walk.mcfunction',
#  '../functions\\titans\\mobs\\6\\attack\\1.mcfunction',
#  '../functions\\titans\\mobs\\6\\attack\\2.mcfunction',
#  '../functions\\titans\\mobs\\6\\attack\\main.mcfunction',
#  '../functions\\titans\\mobs\\7\\animate\\idle.mcfunction',
#  '../functions\\titans\\mobs\\7\\animate\\walk.mcfunction',
#  '../functions\\titans\\mobs\\8\\animate\\attack.mcfunction',
#  '../functions\\titans\\mobs\\8\\animate\\attack_2.mcfunction',
#  '../functions\\titans\\mobs\\8\\animate\\idle.mcfunction',
#  ...]

# %%
# A list to store the paths of files containing the search string
matching_files = []

for delete_function in delete_functions:
    # print("checking: ",delete_function)
    for file_path in file_paths:
        try:
            with open(file_path, 'r') as file:
                file_contents = file.read()
                if delete_function[1] in file_contents:
                    delete_function[0] = True
                    #matching_files.append(file_path)
        except Exception as e:
            # Handle exceptions like file not found, permission denied, etc.
            print(f"Error reading {file_path}: {str(e)}")
    if not(delete_function[0]):
        print("Delete: ",delete_function)
# Out:
# Delete:  [False, 'function snc:give/diary/peng']
# Delete:  [False, 'function snc:give/guide/shifters']
# Delete:  [False, 'function snc:give/guide/titan_war']
# Delete:  [False, 'function snc:give/guide/village']
# Delete:  [False, 'function snc:give/item/armor/skull']
# Delete:  [False, 'function snc:give/item/attack/skull']
# Delete:  [False, 'function snc:give/item/shifters/add_2']
# Delete:  [False, 'function snc:give/item/shifters/primary']
# Delete:  [False, 'function snc:give/item/shifters/syringe/royal']
# Delete:  [False, 'function snc:give/item/villager/magus']
# Delete:  [False, 'function snc:item/return/sex']
# Delete:  [False, 'function snc:logic/manual/init']
# Delete:  [False, 'function snc:logic/quest/alex/adv']
# Delete:  [False, 'function snc:logic/quest/bob/main']
# Delete:  [False, 'function snc:logic/quest/bomb/adv']
# Delete:  [False, 'function snc:logic/quest/niflum/adv']
# Delete:  [False, 'function snc:logic/quest/ragnaar/adv']
# Delete:  [False, 'function snc:logic/rotate/main']
# Delete:  [False, 'function snc:player/build/stand/toy']
# Delete:  [False, 'function snc:player/odm/fall_damage']
# Delete:  [False, 'function snc:player/titan/infect/human']
# Delete:  [False, 'function snc:player/titan/injection/adv']
# Delete:  [False, 'function snc:player/titan/injection/check_villager']
# Delete:  [False, 'function snc:player/titan/injection/display']
# Delete:  [False, 'function snc:shifters/mobs/kill_old']
# Delete:  [False, 'function snc:shifters/mobs/armor/curse']
# Delete:  [False, 'function snc:shifters/mobs/armor/hitbox']
# Delete:  [False, 'function snc:shifters/mobs/armor/model']
# Delete:  [False, 'function snc:shifters/mobs/armor/spawn']
# Delete:  [False, 'function snc:shifters/mobs/armor/animate/bite']
# Delete:  [False, 'function snc:shifters/mobs/armor/animate/roar']
# Delete:  [False, 'function snc:shifters/mobs/attack/curse']
# Delete:  [False, 'function snc:shifters/mobs/attack/hitbox']
# Delete:  [False, 'function snc:shifters/mobs/attack/model']
# Delete:  [False, 'function snc:shifters/mobs/attack/spawn']
# Delete:  [False, 'function snc:shifters/mobs/attack/animate/bite']
# Delete:  [False, 'function snc:shifters/mobs/attack/animate/roar']
# Delete:  [False, 'function snc:shifters/mobs/beast/curse']
# Delete:  [False, 'function snc:shifters/mobs/beast/hitbox']
# Delete:  [False, 'function snc:shifters/mobs/beast/model']
# Delete:  [False, 'function snc:shifters/mobs/beast/spawn']
# Delete:  [False, 'function snc:shifters/mobs/beast/animate/bite']
# Delete:  [False, 'function snc:shifters/mobs/beast/animate/block']
# Delete:  [False, 'function snc:shifters/mobs/beast/animate/kick_1']
# Delete:  [False, 'function snc:shifters/mobs/beast/animate/kick_2']
# Delete:  [False, 'function snc:shifters/mobs/beast/animate/kick_3']
# Delete:  [False, 'function snc:shifters/mobs/beast/animate/roar']
# Delete:  [False, 'function snc:shifters/mobs/cart/curse']
# Delete:  [False, 'function snc:shifters/mobs/cart/hitbox']
# Delete:  [False, 'function snc:shifters/mobs/cart/model']
# Delete:  [False, 'function snc:shifters/mobs/cart/spawn']
# Delete:  [False, 'function snc:shifters/mobs/cart/animate/bite']
# Delete:  [False, 'function snc:shifters/mobs/cart/animate/roar']
# Delete:  [False, 'function snc:shifters/mobs/cart/animate/run']
# Delete:  [False, 'function snc:shifters/mobs/cart/animate/sneak']
# Delete:  [False, 'function snc:shifters/mobs/colossal/curse']
# Delete:  [False, 'function snc:shifters/mobs/colossal/hitbox']
# Delete:  [False, 'function snc:shifters/mobs/colossal/model']
# Delete:  [False, 'function snc:shifters/mobs/colossal/spawn']
# Delete:  [False, 'function snc:shifters/mobs/colossal/animate/bite']
# Delete:  [False, 'function snc:shifters/mobs/colossal/animate/roar']
# Delete:  [False, 'function snc:shifters/mobs/colossal/animate/run']
# Delete:  [False, 'function snc:shifters/mobs/colossal/animate/sneak']
# Delete:  [False, 'function snc:titans/c']
# Delete:  [False, 'function snc:titans/mobs/c/animate/walk']

# %%
# Filter and print sub-arrays with the first element as False
for sub_array in delete_functions:
    if sub_array[0] is False:
        print(sub_array)
# Out:
# [False, 'function snc:give/diary/peng']
# [False, 'function snc:give/guide/shifters']
# [False, 'function snc:give/guide/titan_war']
# [False, 'function snc:give/guide/village']
# [False, 'function snc:give/item/armor/skull']
# [False, 'function snc:give/item/attack/skull']
# [False, 'function snc:give/item/shifters/add_2']
# [False, 'function snc:give/item/shifters/primary']
# [False, 'function snc:give/item/shifters/syringe/royal']
# [False, 'function snc:give/item/villager/magus']
# [False, 'function snc:item/return/sex']
# [False, 'function snc:logic/manual/init']
# [False, 'function snc:logic/quest/alex/adv']
# [False, 'function snc:logic/quest/bob/main']
# [False, 'function snc:logic/quest/bomb/adv']
# [False, 'function snc:logic/quest/niflum/adv']
# [False, 'function snc:logic/quest/ragnaar/adv']
# [False, 'function snc:logic/rotate/main']
# [False, 'function snc:player/build/stand/toy']
# [False, 'function snc:player/odm/fall_damage']
# [False, 'function snc:player/titan/infect/human']
# [False, 'function snc:player/titan/injection/adv']
# [False, 'function snc:player/titan/injection/check_villager']
# [False, 'function snc:player/titan/injection/display']
# [False, 'function snc:shifters/mobs/kill_old']
# [False, 'function snc:shifters/mobs/armor/curse']
# [False, 'function snc:shifters/mobs/armor/hitbox']
# [False, 'function snc:shifters/mobs/armor/model']
# [False, 'function snc:shifters/mobs/armor/spawn']
# [False, 'function snc:shifters/mobs/armor/animate/bite']
# [False, 'function snc:shifters/mobs/armor/animate/roar']
# [False, 'function snc:shifters/mobs/attack/curse']
# [False, 'function snc:shifters/mobs/attack/hitbox']
# [False, 'function snc:shifters/mobs/attack/model']
# [False, 'function snc:shifters/mobs/attack/spawn']
# [False, 'function snc:shifters/mobs/attack/animate/bite']
# [False, 'function snc:shifters/mobs/attack/animate/roar']
# [False, 'function snc:shifters/mobs/beast/curse']
# [False, 'function snc:shifters/mobs/beast/hitbox']
# [False, 'function snc:shifters/mobs/beast/model']
# [False, 'function snc:shifters/mobs/beast/spawn']
# [False, 'function snc:shifters/mobs/beast/animate/bite']
# [False, 'function snc:shifters/mobs/beast/animate/block']
# [False, 'function snc:shifters/mobs/beast/animate/kick_1']
# [False, 'function snc:shifters/mobs/beast/animate/kick_2']
# [False, 'function snc:shifters/mobs/beast/animate/kick_3']
# [False, 'function snc:shifters/mobs/beast/animate/roar']
# [False, 'function snc:shifters/mobs/cart/curse']
# [False, 'function snc:shifters/mobs/cart/hitbox']
# [False, 'function snc:shifters/mobs/cart/model']
# [False, 'function snc:shifters/mobs/cart/spawn']
# [False, 'function snc:shifters/mobs/cart/animate/bite']
# [False, 'function snc:shifters/mobs/cart/animate/roar']
# [False, 'function snc:shifters/mobs/cart/animate/run']
# [False, 'function snc:shifters/mobs/cart/animate/sneak']
# [False, 'function snc:shifters/mobs/colossal/curse']
# [False, 'function snc:shifters/mobs/colossal/hitbox']
# [False, 'function snc:shifters/mobs/colossal/model']
# [False, 'function snc:shifters/mobs/colossal/spawn']
# [False, 'function snc:shifters/mobs/colossal/animate/bite']
# [False, 'function snc:shifters/mobs/colossal/animate/roar']
# [False, 'function snc:shifters/mobs/colossal/animate/run']
# [False, 'function snc:shifters/mobs/colossal/animate/sneak']
# [False, 'function snc:titans/c']
# [False, 'function snc:titans/mobs/c/animate/walk']
